# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/global-wheat-detection/sample_submission.csv
# /kaggle/input/global-wheat-detection/train.csv
# /kaggle/input/global-wheat-detection/test/796707dd7.jpg
# /kaggle/input/global-wheat-detection/test/2fd875eaa.jpg
# /kaggle/input/global-wheat-detection/test/cc3532ff6.jpg
# /kaggle/input/global-wheat-detection/test/53f253011.jpg
# /kaggle/input/global-wheat-detection/test/f5a1f0358.jpg
# /kaggle/input/global-wheat-detection/test/51f1be19e.jpg
# /kaggle/input/global-wheat-detection/test/aac893a91.jpg
# /kaggle/input/global-wheat-detection/test/cb8d261a3.jpg
# /kaggle/input/global-wheat-detection/test/51b3e36ab.jpg
# /kaggle/input/global-wheat-detection/test/348a992bb.jpg
# /kaggle/input/global-wheat-detection/train/944c60a15.jpg
# /kaggle/input/global-wheat-detection/train/dd5dd0234.jpg
# /kaggle/input/global-wheat-detection/train/72f8aaa4f.jpg
# /kaggle/input/global-wheat-detection/train/69595016d.jpg
# /kaggle/input/global-wheat-detection/train/28b8ba0aa.jpg
# /kaggle/input/global-wheat-detection/train/2d635716b.jpg
# /kaggle/input/global-wheat-detection/train/1f548e2f2.jpg
# /kaggle/input/global-wheat-detection/train/47b0d504c.jpg
# /kaggle/input/global-wheat-detection/train/e34336025.jpg
# /kaggle/input/global-wheat-detection/train/2d990708e.jpg
# /kaggle/input/global-wheat-detection/train/3842535e1.jpg
# /kaggle/input/global-wheat-detection/train/a673347b1.jpg
# /kaggle/input/global-wheat-detection/train/901e23e9b.jpg
# /kaggle/input/global-wheat-detection/train/5dcae81a5.jpg
# /kaggle/input/global-wheat-detection/train/dec23c826.jpg
# /kaggle/input/global-wheat-detection/train/eaeda7363.jpg
# /kaggle/input/global-wheat-detection/train/bc1666f8c.jpg
# /kaggle/input/global-wheat-detection/train/0877092cc.jpg
# /kaggle/input/global-wheat-detection/train/609c993a9.jpg
# /kaggle/input/global-wheat-detection/train/e1e3b78ab.jpg
# /kaggle/input/global-wheat-detection/train/04a47965e.jpg
# /kaggle/input/global-wheat-detection/train/5e0747034.jpg
# /kaggle/input/global-wheat-detection/train/2e262da1c.jpg
# /kaggle/input/global-wheat-detection/train/07f519e11.jpg
# /kaggle/input/global-wheat-detection/train/22c8f2030.jpg
# /kaggle/input/global-wheat-detection/train/ab9e2d432.jpg
# /kaggle/input/global-wheat-detection/train/134d4a01c.jpg
# /kaggle/input/global-wheat-detection/train/80dbba8a7.jpg
# /kaggle/input/global-wheat-detection/train/8ba166588.jpg
# /kaggle/input/global-wheat-detection/train/ca5e51e59.jpg
# /kaggle/input/global-wheat-detection/train/952ce366b.jpg
# /kaggle/input/global-wheat-detection/train/f3ed7c4ee.jpg
# /kaggle/input/global-wheat-detection/train/798a261f0.jpg
# /kaggle/input/global-wheat-detection/train/9780d64f5.jpg
# /kaggle/input/global-wheat-detection/train/b1e4a723e.jpg
# /kaggle/input/global-wheat-detection/train/630b12b1a.jpg
# /kaggle/input/global-wheat-detection/train/e40dcc2bf.jpg
# /kaggle/input/global-wheat-detection/train/1f9a8abcd.jpg
# /kaggle/input/global-wheat-detection/train/5ec31deb1.jpg
# /kaggle/input/global-wheat-detection/train/05cd43275.jpg
# /kaggle/input/global-wheat-detection/train/303def58d.jpg
# /kaggle/input/global-wheat-detection/train/5792ad7e6.jpg
# /kaggle/input/global-wheat-detection/train/bd9083329.jpg
# /kaggle/input/global-wheat-detection/train/55deda461.jpg
# /kaggle/input/global-wheat-detection/train/f01ed3f24.jpg
# /kaggle/input/global-wheat-detection/train/498df3cb2.jpg
# /kaggle/input/global-wheat-detection/train/ee91a1343.jpg
# /kaggle/input/global-wheat-detection/train/7de1fc333.jpg
# /kaggle/input/global-wheat-detection/train/7b89e388a.jpg
# /kaggle/input/global-wheat-detection/train/9f1723100.jpg
# /kaggle/input/global-wheat-detection/train/90677210d.jpg
# /kaggle/input/global-wheat-detection/train/c15a563d8.jpg
# /kaggle/input/global-wheat-detection/train/3c2b5bd45.jpg
# /kaggle/input/global-wheat-detection/train/fbc79aea4.jpg
# /kaggle/input/global-wheat-detection/train/a897f8dc8.jpg
# /kaggle/input/global-wheat-detection/train/66adaf07a.jpg
# /kaggle/input/global-wheat-detection/train/1914c04d6.jpg
# /kaggle/input/global-wheat-detection/train/2d80f9c49.jpg
# /kaggle/input/global-wheat-detection/train/91b435dbb.jpg
# /kaggle/input/global-wheat-detection/train/4c572095f.jpg
# /kaggle/input/global-wheat-detection/train/3ae057d35.jpg
# /kaggle/input/global-wheat-detection/train/522b1ba70.jpg
# /kaggle/input/global-wheat-detection/train/b5e7db94b.jpg
# /kaggle/input/global-wheat-detection/train/e84d2bbd1.jpg
# /kaggle/input/global-wheat-detection/train/e6e48fa5d.jpg
# /kaggle/input/global-wheat-detection/train/ac6b1b3a3.jpg
# /kaggle/input/global-wheat-detection/train/644eff133.jpg
# /kaggle/input/global-wheat-detection/train/0980aa079.jpg
# /kaggle/input/global-wheat-detection/train/a4fb1f6af.jpg
# /kaggle/input/global-wheat-detection/train/701c2e3e9.jpg
# /kaggle/input/global-wheat-detection/train/6e7c6ce51.jpg
# /kaggle/input/global-wheat-detection/train/a0b9b2399.jpg
# /kaggle/input/global-wheat-detection/train/87196861b.jpg
# /kaggle/input/global-wheat-detection/train/077ba8cca.jpg
# /kaggle/input/global-wheat-detection/train/1c0155c9c.jpg
# /kaggle/input/global-wheat-detection/train/f7ec99608.jpg
# /kaggle/input/global-wheat-detection/train/f6b9d6dd1.jpg
# /kaggle/input/global-wheat-detection/train/c2fd0893f.jpg
# /kaggle/input/global-wheat-detection/train/b6b899073.jpg
# /kaggle/input/global-wheat-detection/train/18f8b24f1.jpg
# /kaggle/input/global-wheat-detection/train/69662aa1c.jpg
# /kaggle/input/global-wheat-detection/train/6bc82b5c6.jpg
# /kaggle/input/global-wheat-detection/train/463a95dac.jpg
# /kaggle/input/global-wheat-detection/train/421657e44.jpg
# /kaggle/input/global-wheat-detection/train/509a7a9b5.jpg
# /kaggle/input/global-wheat-detection/train/44afd181e.jpg
# /kaggle/input/global-wheat-detection/train/19f4faf0f.jpg
# /kaggle/input/global-wheat-detection/train/58cef5c6c.jpg
# /kaggle/input/global-wheat-detection/train/41badd217.jpg
# /kaggle/input/global-wheat-detection/train/ab500e0d8.jpg
# /kaggle/input/global-wheat-detection/train/53099e7e0.jpg
# /kaggle/input/global-wheat-detection/train/83a5d8ac8.jpg
# /kaggle/input/global-wheat-detection/train/48fe9c634.jpg
# /kaggle/input/global-wheat-detection/train/7257fdd84.jpg
# /kaggle/input/global-wheat-detection/train/9d0eb23a0.jpg
# /kaggle/input/global-wheat-detection/train/1e58125ec.jpg
# /kaggle/input/global-wheat-detection/train/da9b730d9.jpg
# /kaggle/input/global-wheat-detection/train/14e9933bb.jpg
# /kaggle/input/global-wheat-detection/train/b900ef546.jpg
# /kaggle/input/global-wheat-detection/train/1734d7a9f.jpg
# /kaggle/input/global-wheat-detection/train/53d0a8b5a.jpg
# /kaggle/input/global-wheat-detection/train/ecd58cc0a.jpg
# /kaggle/input/global-wheat-detection/train/765f1b36a.jpg
# /kaggle/input/global-wheat-detection/train/c0fa19bac.jpg
# /kaggle/input/global-wheat-detection/train/24a90b0dd.jpg
# /kaggle/input/global-wheat-detection/train/e8e90e8db.jpg
# /kaggle/input/global-wheat-detection/train/a519e5a11.jpg
# /kaggle/input/global-wheat-detection/train/ee8c82355.jpg
# /kaggle/input/global-wheat-detection/train/14fd84198.jpg
# /kaggle/input/global-wheat-detection/train/5780f8065.jpg
# /kaggle/input/global-wheat-detection/train/2f204a70c.jpg
# /kaggle/input/global-wheat-detection/train/faedfa626.jpg
# /kaggle/input/global-wheat-detection/train/e2e2b0975.jpg
# /kaggle/input/global-wheat-detection/train/783a00fe3.jpg
# /kaggle/input/global-wheat-detection/train/5901a73fe.jpg
# /kaggle/input/global-wheat-detection/train/91fefb8e4.jpg
# /kaggle/input/global-wheat-detection/train/725c243a7.jpg
# /kaggle/input/global-wheat-detection/train/e837f4e67.jpg
# /kaggle/input/global-wheat-detection/train/2a5be9325.jpg
# /kaggle/input/global-wheat-detection/train/a0e06275c.jpg
# /kaggle/input/global-wheat-detection/train/a28dcf45d.jpg
# /kaggle/input/global-wheat-detection/train/475d3a571.jpg
# /kaggle/input/global-wheat-detection/train/c35347675.jpg
# /kaggle/input/global-wheat-detection/train/060fd0cd8.jpg
# /kaggle/input/global-wheat-detection/train/f8e590769.jpg
# /kaggle/input/global-wheat-detection/train/39614e195.jpg
# /kaggle/input/global-wheat-detection/train/7b138337f.jpg
# /kaggle/input/global-wheat-detection/train/f57f7edd1.jpg
# /kaggle/input/global-wheat-detection/train/9e15ceea4.jpg
# /kaggle/input/global-wheat-detection/train/9858d67dc.jpg
# /kaggle/input/global-wheat-detection/train/57587eaf7.jpg
# /kaggle/input/global-wheat-detection/train/060543bbf.jpg
# /kaggle/input/global-wheat-detection/train/764c88483.jpg
# /kaggle/input/global-wheat-detection/train/3a1f54e49.jpg
# /kaggle/input/global-wheat-detection/train/92dbf3418.jpg
# /kaggle/input/global-wheat-detection/train/56fd2d9c7.jpg
# /kaggle/input/global-wheat-detection/train/88136bbdd.jpg
# /kaggle/input/global-wheat-detection/train/773bf9022.jpg
# /kaggle/input/global-wheat-detection/train/4b127eb47.jpg
# /kaggle/input/global-wheat-detection/train/f6181ac93.jpg
# /kaggle/input/global-wheat-detection/train/8a948e84b.jpg
# /kaggle/input/global-wheat-detection/train/0dbfcf802.jpg
# /kaggle/input/global-wheat-detection/train/311a6b1e4.jpg
# /kaggle/input/global-wheat-detection/train/a97e8476c.jpg
# /kaggle/input/global-wheat-detection/train/b7d03627f.jpg
# /kaggle/input/global-wheat-detection/train/de941b2fc.jpg
# /kaggle/input/global-wheat-detection/train/614b1d8c5.jpg
# /kaggle/input/global-wheat-detection/train/75735abbc.jpg
# /kaggle/input/global-wheat-detection/train/6db264b94.jpg
# /kaggle/input/global-wheat-detection/train/566c90045.jpg
# /kaggle/input/global-wheat-detection/train/3c0d9abaa.jpg
# /kaggle/input/global-wheat-detection/train/1f387ec08.jpg
# /kaggle/input/global-wheat-detection/train/41761631b.jpg
# /kaggle/input/global-wheat-detection/train/e46378032.jpg
# /kaggle/input/global-wheat-detection/train/5b36bb79a.jpg
# /kaggle/input/global-wheat-detection/train/ac47b0c64.jpg
# /kaggle/input/global-wheat-detection/train/dfc6a2bcc.jpg
# /kaggle/input/global-wheat-detection/train/ab891997e.jpg
# /kaggle/input/global-wheat-detection/train/3edfa2df0.jpg
# /kaggle/input/global-wheat-detection/train/26d7e7074.jpg
# /kaggle/input/global-wheat-detection/train/19fdbeb90.jpg
# /kaggle/input/global-wheat-detection/train/655532cc7.jpg
# /kaggle/input/global-wheat-detection/train/eee4c334e.jpg
# /kaggle/input/global-wheat-detection/train/ad67b76a3.jpg
# /kaggle/input/global-wheat-detection/train/8200547cf.jpg
# /kaggle/input/global-wheat-detection/train/33ea56e1c.jpg
# /kaggle/input/global-wheat-detection/train/7264c58b9.jpg
# /kaggle/input/global-wheat-detection/train/e92e52948.jpg
# /kaggle/input/global-wheat-detection/train/c6ca898c2.jpg
# /kaggle/input/global-wheat-detection/train/5ab074c28.jpg
# /kaggle/input/global-wheat-detection/train/0785826af.jpg
# /kaggle/input/global-wheat-detection/train/a30ad4024.jpg
# /kaggle/input/global-wheat-detection/train/498261a4b.jpg
# /kaggle/input/global-wheat-detection/train/2e1ed4321.jpg
# /kaggle/input/global-wheat-detection/train/e4b7e3af6.jpg
# /kaggle/input/global-wheat-detection/train/73ebcf532.jpg
# /kaggle/input/global-wheat-detection/train/a685fbf20.jpg
# /kaggle/input/global-wheat-detection/train/c1cdb43d9.jpg
# /kaggle/input/global-wheat-detection/train/1d554c619.jpg
# /kaggle/input/global-wheat-detection/train/65d6480b2.jpg
# /kaggle/input/global-wheat-detection/train/7ec61f6ab.jpg
# /kaggle/input/global-wheat-detection/train/115d07916.jpg
# /kaggle/input/global-wheat-detection/train/2ae1f9d88.jpg
# /kaggle/input/global-wheat-detection/train/a6afb2315.jpg
# /kaggle/input/global-wheat-detection/train/b696f57e0.jpg
# /kaggle/input/global-wheat-detection/train/09bcc5259.jpg
# /kaggle/input/global-wheat-detection/train/2f9755f66.jpg
# /kaggle/input/global-wheat-detection/train/fb456d16f.jpg
# /kaggle/input/global-wheat-detection/train/57284abbb.jpg
# /kaggle/input/global-wheat-detection/train/f05cd0112.jpg
# /kaggle/input/global-wheat-detection/train/4a29d08ab.jpg
# /kaggle/input/global-wheat-detection/train/8a7d9b4b0.jpg
# /kaggle/input/global-wheat-detection/train/9d9b579c6.jpg
# /kaggle/input/global-wheat-detection/train/96367fda5.jpg
# /kaggle/input/global-wheat-detection/train/84e6957ae.jpg
# /kaggle/input/global-wheat-detection/train/ed88cccdc.jpg
# /kaggle/input/global-wheat-detection/train/010b216d4.jpg
# /kaggle/input/global-wheat-detection/train/7a77062fb.jpg
# /kaggle/input/global-wheat-detection/train/f43b1b260.jpg
# /kaggle/input/global-wheat-detection/train/ad59fa99c.jpg
# /kaggle/input/global-wheat-detection/train/03d831c0d.jpg
# /kaggle/input/global-wheat-detection/train/452fe4932.jpg
# /kaggle/input/global-wheat-detection/train/41f3feb3c.jpg
# /kaggle/input/global-wheat-detection/train/1f255e0c5.jpg
# /kaggle/input/global-wheat-detection/train/5baa23af0.jpg
# /kaggle/input/global-wheat-detection/train/ade6dd872.jpg
# /kaggle/input/global-wheat-detection/train/9c29fd766.jpg
# /kaggle/input/global-wheat-detection/train/d1ff5f449.jpg
# /kaggle/input/global-wheat-detection/train/00e903abe.jpg
# /kaggle/input/global-wheat-detection/train/1970cbf85.jpg
# /kaggle/input/global-wheat-detection/train/97f0e1800.jpg
# /kaggle/input/global-wheat-detection/train/1ebc11f19.jpg
# /kaggle/input/global-wheat-detection/train/895420d9f.jpg
# /kaggle/input/global-wheat-detection/train/7f065f0ec.jpg
# /kaggle/input/global-wheat-detection/train/4c5805bae.jpg
# /kaggle/input/global-wheat-detection/train/41c0123cc.jpg
# /kaggle/input/global-wheat-detection/train/695cd49dd.jpg
# /kaggle/input/global-wheat-detection/train/ffaa964a2.jpg
# /kaggle/input/global-wheat-detection/train/633807391.jpg
# /kaggle/input/global-wheat-detection/train/0dd534f81.jpg
# /kaggle/input/global-wheat-detection/train/2d0fc19b8.jpg
# /kaggle/input/global-wheat-detection/train/e891a6cff.jpg
# /kaggle/input/global-wheat-detection/train/ad3fea21b.jpg
# /kaggle/input/global-wheat-detection/train/3d9125515.jpg
# /kaggle/input/global-wheat-detection/train/e891c64c3.jpg
# /kaggle/input/global-wheat-detection/train/7bf6e7991.jpg
# /kaggle/input/global-wheat-detection/train/c60a61cf5.jpg
# /kaggle/input/global-wheat-detection/train/772287113.jpg
# /kaggle/input/global-wheat-detection/train/a815bae49.jpg
# /kaggle/input/global-wheat-detection/train/a1fcb07dd.jpg
# /kaggle/input/global-wheat-detection/train/b46dce732.jpg
# /kaggle/input/global-wheat-detection/train/8851db816.jpg
# /kaggle/input/global-wheat-detection/train/9043b1fcf.jpg
# /kaggle/input/global-wheat-detection/train/ab81b2342.jpg
# /kaggle/input/global-wheat-detection/train/a28d1eb6d.jpg
# /kaggle/input/global-wheat-detection/train/b80ec5988.jpg
# /kaggle/input/global-wheat-detection/train/834690a35.jpg
# /kaggle/input/global-wheat-detection/train/a6a921e82.jpg
# /kaggle/input/global-wheat-detection/train/4f13bffbc.jpg
# /kaggle/input/global-wheat-detection/train/2e6c333a7.jpg
# /kaggle/input/global-wheat-detection/train/19fd72f8b.jpg
# /kaggle/input/global-wheat-detection/train/bf2d1a625.jpg
# /kaggle/input/global-wheat-detection/train/b3822b5cd.jpg
# /kaggle/input/global-wheat-detection/train/769847044.jpg
# /kaggle/input/global-wheat-detection/train/d25b61e9f.jpg
# /kaggle/input/global-wheat-detection/train/dfbc049cd.jpg
# /kaggle/input/global-wheat-detection/train/ba98d009b.jpg
# /kaggle/input/global-wheat-detection/train/8e2f178d1.jpg
# /kaggle/input/global-wheat-detection/train/aadb83e1d.jpg
# /kaggle/input/global-wheat-detection/train/aff4e0a02.jpg
# /kaggle/input/global-wheat-detection/train/1f7600e2c.jpg
# /kaggle/input/global-wheat-detection/train/7c3c4d604.jpg
# /kaggle/input/global-wheat-detection/train/51d7e0c3d.jpg
# /kaggle/input/global-wheat-detection/train/afb7671e5.jpg
# /kaggle/input/global-wheat-detection/train/4130b2b02.jpg
# /kaggle/input/global-wheat-detection/train/6b0b7bbd9.jpg
# /kaggle/input/global-wheat-detection/train/9fe944c85.jpg
# /kaggle/input/global-wheat-detection/train/46b7a42f3.jpg
# /kaggle/input/global-wheat-detection/train/990c1777d.jpg
# /kaggle/input/global-wheat-detection/train/de3c12de1.jpg
# /kaggle/input/global-wheat-detection/train/b13f38e6f.jpg
# /kaggle/input/global-wheat-detection/train/07ebc6045.jpg
# /kaggle/input/global-wheat-detection/train/a489c82f1.jpg
# /kaggle/input/global-wheat-detection/train/3834dbe25.jpg
# /kaggle/input/global-wheat-detection/train/ebaa9b7d6.jpg
# /kaggle/input/global-wheat-detection/train/0e2be222f.jpg
# /kaggle/input/global-wheat-detection/train/b2fbd25ac.jpg
# /kaggle/input/global-wheat-detection/train/de0f984ca.jpg
# /kaggle/input/global-wheat-detection/train/625c80346.jpg
# /kaggle/input/global-wheat-detection/train/cabe03050.jpg
# /kaggle/input/global-wheat-detection/train/8fb545c05.jpg
# /kaggle/input/global-wheat-detection/train/69855d3de.jpg
# /kaggle/input/global-wheat-detection/train/e16e3b2c6.jpg
# /kaggle/input/global-wheat-detection/train/03a988adf.jpg
# /kaggle/input/global-wheat-detection/train/5a5631a48.jpg
# /kaggle/input/global-wheat-detection/train/d60e832a5.jpg
# /kaggle/input/global-wheat-detection/train/156282051.jpg
# /kaggle/input/global-wheat-detection/train/63fe1ddab.jpg
# /kaggle/input/global-wheat-detection/train/619cb231d.jpg
# /kaggle/input/global-wheat-detection/train/3e9bf50b6.jpg
# /kaggle/input/global-wheat-detection/train/9983d297c.jpg
# /kaggle/input/global-wheat-detection/train/4be2817ef.jpg
# /kaggle/input/global-wheat-detection/train/46e480374.jpg
# /kaggle/input/global-wheat-detection/train/43a765c3e.jpg
# /kaggle/input/global-wheat-detection/train/c01a58fdb.jpg
# /kaggle/input/global-wheat-detection/train/059125072.jpg
# /kaggle/input/global-wheat-detection/train/e4b256788.jpg
# /kaggle/input/global-wheat-detection/train/990188afc.jpg
# /kaggle/input/global-wheat-detection/train/b615a1f5c.jpg
# /kaggle/input/global-wheat-detection/train/69b3074c4.jpg
# /kaggle/input/global-wheat-detection/train/aedca9e2e.jpg
# /kaggle/input/global-wheat-detection/train/7c659d49a.jpg
# /kaggle/input/global-wheat-detection/train/cf483de89.jpg
# /kaggle/input/global-wheat-detection/train/2041a2d49.jpg
# /kaggle/input/global-wheat-detection/train/2dbaac896.jpg
# /kaggle/input/global-wheat-detection/train/cb0a32cbb.jpg
# /kaggle/input/global-wheat-detection/train/26a2693ec.jpg
# /kaggle/input/global-wheat-detection/train/ce69098f5.jpg
# /kaggle/input/global-wheat-detection/train/9637519d2.jpg
# /kaggle/input/global-wheat-detection/train/556c18af4.jpg
# /kaggle/input/global-wheat-detection/train/d3b3b5628.jpg
# /kaggle/input/global-wheat-detection/train/030314634.jpg
# /kaggle/input/global-wheat-detection/train/b4cfcce63.jpg
# /kaggle/input/global-wheat-detection/train/9a34996be.jpg
# /kaggle/input/global-wheat-detection/train/b7c97a57b.jpg
# /kaggle/input/global-wheat-detection/train/88707bd69.jpg
# /kaggle/input/global-wheat-detection/train/6a1ad8811.jpg
# /kaggle/input/global-wheat-detection/train/d3b4a0cdf.jpg
# /kaggle/input/global-wheat-detection/train/7c3570738.jpg
# /kaggle/input/global-wheat-detection/train/84cdd23e4.jpg
# /kaggle/input/global-wheat-detection/train/7be932521.jpg
# /kaggle/input/global-wheat-detection/train/2b7b5621c.jpg
# /kaggle/input/global-wheat-detection/train/af1f9ee99.jpg
# /kaggle/input/global-wheat-detection/train/e6af2a27e.jpg
# /kaggle/input/global-wheat-detection/train/0eab04c31.jpg
# /kaggle/input/global-wheat-detection/train/8b963f326.jpg
# /kaggle/input/global-wheat-detection/train/56105ed87.jpg
# /kaggle/input/global-wheat-detection/train/f1ecbf9d4.jpg
# /kaggle/input/global-wheat-detection/train/c6e6f5527.jpg
# /kaggle/input/global-wheat-detection/train/08aa26ac1.jpg
# /kaggle/input/global-wheat-detection/train/a36608629.jpg
# /kaggle/input/global-wheat-detection/train/ad94558cf.jpg
# /kaggle/input/global-wheat-detection/train/0fd63ed98.jpg
# /kaggle/input/global-wheat-detection/train/ae1ec9804.jpg
# /kaggle/input/global-wheat-detection/train/b8ddb6c73.jpg
# /kaggle/input/global-wheat-detection/train/7ab4f3778.jpg
# /kaggle/input/global-wheat-detection/train/144d57df8.jpg
# /kaggle/input/global-wheat-detection/train/39ad9affa.jpg
# /kaggle/input/global-wheat-detection/train/32f716667.jpg
# /kaggle/input/global-wheat-detection/train/4c02b2f7f.jpg
# /kaggle/input/global-wheat-detection/train/f8f466cc9.jpg
# /kaggle/input/global-wheat-detection/train/c64a4006c.jpg
# /kaggle/input/global-wheat-detection/train/d22905ef2.jpg
# /kaggle/input/global-wheat-detection/train/d606fe447.jpg
# /kaggle/input/global-wheat-detection/train/bbce58f71.jpg
# /kaggle/input/global-wheat-detection/train/33b939a6a.jpg
# /kaggle/input/global-wheat-detection/train/f6a53d30e.jpg
# /kaggle/input/global-wheat-detection/train/e11b95f4e.jpg
# /kaggle/input/global-wheat-detection/train/876e9fc9b.jpg
# /kaggle/input/global-wheat-detection/train/d69f6d767.jpg
# /kaggle/input/global-wheat-detection/train/43d29ec95.jpg
# /kaggle/input/global-wheat-detection/train/76f679a5c.jpg
# /kaggle/input/global-wheat-detection/train/b6a159fd4.jpg
# /kaggle/input/global-wheat-detection/train/1b5e821f9.jpg
# /kaggle/input/global-wheat-detection/train/3cbee7440.jpg
# /kaggle/input/global-wheat-detection/train/b5264e0ad.jpg
# /kaggle/input/global-wheat-detection/train/d950bfe39.jpg
# /kaggle/input/global-wheat-detection/train/c00c660fc.jpg
# /kaggle/input/global-wheat-detection/train/84a5579db.jpg
# /kaggle/input/global-wheat-detection/train/48dd5506a.jpg
# /kaggle/input/global-wheat-detection/train/5f0b34ad6.jpg
# /kaggle/input/global-wheat-detection/train/6dbd83602.jpg
# /kaggle/input/global-wheat-detection/train/77f6e7caf.jpg
# /kaggle/input/global-wheat-detection/train/9595d8dc6.jpg
# /kaggle/input/global-wheat-detection/train/8f3e2b4e8.jpg
# /kaggle/input/global-wheat-detection/train/93d67b171.jpg
# /kaggle/input/global-wheat-detection/train/4a3f67d2e.jpg
# /kaggle/input/global-wheat-detection/train/25d38ec2c.jpg
# /kaggle/input/global-wheat-detection/train/75132304c.jpg
# /kaggle/input/global-wheat-detection/train/a4bce62ff.jpg
# /kaggle/input/global-wheat-detection/train/ac4e4e682.jpg
# /kaggle/input/global-wheat-detection/train/286af845e.jpg
# /kaggle/input/global-wheat-detection/train/8782ac4b6.jpg
# /kaggle/input/global-wheat-detection/train/2dda3a53d.jpg
# /kaggle/input/global-wheat-detection/train/2cc49e1ba.jpg
# /kaggle/input/global-wheat-detection/train/42c7bc230.jpg
# /kaggle/input/global-wheat-detection/train/0afdb91a2.jpg
# /kaggle/input/global-wheat-detection/train/d1b7acd1d.jpg
# /kaggle/input/global-wheat-detection/train/77d1f3c18.jpg
# /kaggle/input/global-wheat-detection/train/a18ff674f.jpg
# /kaggle/input/global-wheat-detection/train/687972820.jpg
# /kaggle/input/global-wheat-detection/train/e3fcdaef7.jpg
# /kaggle/input/global-wheat-detection/train/b95e8d11b.jpg
# /kaggle/input/global-wheat-detection/train/763327404.jpg
# /kaggle/input/global-wheat-detection/train/defc112e7.jpg
# /kaggle/input/global-wheat-detection/train/ebc1c07c1.jpg
# /kaggle/input/global-wheat-detection/train/82890548b.jpg
# /kaggle/input/global-wheat-detection/train/4c8159dbd.jpg
# /kaggle/input/global-wheat-detection/train/286719f2f.jpg
# /kaggle/input/global-wheat-detection/train/0352a6fff.jpg
# /kaggle/input/global-wheat-detection/train/b58605092.jpg
# /kaggle/input/global-wheat-detection/train/b5a90214f.jpg
# /kaggle/input/global-wheat-detection/train/d19c0b3c9.jpg
# /kaggle/input/global-wheat-detection/train/666ca30b3.jpg
# /kaggle/input/global-wheat-detection/train/6284044ed.jpg
# /kaggle/input/global-wheat-detection/train/dac6b76fc.jpg
# /kaggle/input/global-wheat-detection/train/ed1270725.jpg
# /kaggle/input/global-wheat-detection/train/2ad7fa68e.jpg
# /kaggle/input/global-wheat-detection/train/d73cee5d1.jpg
# /kaggle/input/global-wheat-detection/train/124820ed4.jpg
# /kaggle/input/global-wheat-detection/train/f070c6f18.jpg
# /kaggle/input/global-wheat-detection/train/84c56dc93.jpg
# /kaggle/input/global-wheat-detection/train/1856c545d.jpg
# /kaggle/input/global-wheat-detection/train/28d5ba56a.jpg
# /kaggle/input/global-wheat-detection/train/190f2ca1d.jpg
# /kaggle/input/global-wheat-detection/train/0478cbc2a.jpg
# /kaggle/input/global-wheat-detection/train/9e4780f8b.jpg
# /kaggle/input/global-wheat-detection/train/e3d1d796c.jpg
# /kaggle/input/global-wheat-detection/train/5f3d068f1.jpg
# /kaggle/input/global-wheat-detection/train/234cc40aa.jpg
# /kaggle/input/global-wheat-detection/train/bf30984fd.jpg
# /kaggle/input/global-wheat-detection/train/d462add58.jpg
# /kaggle/input/global-wheat-detection/train/0e0a0483e.jpg
# /kaggle/input/global-wheat-detection/train/09798007b.jpg
# /kaggle/input/global-wheat-detection/train/51e3f1a43.jpg
# /kaggle/input/global-wheat-detection/train/2ff4e8bb0.jpg
# /kaggle/input/global-wheat-detection/train/1364f7561.jpg
# /kaggle/input/global-wheat-detection/train/08568d66f.jpg
# /kaggle/input/global-wheat-detection/train/e9d060d22.jpg
# /kaggle/input/global-wheat-detection/train/838e29709.jpg
# /kaggle/input/global-wheat-detection/train/38b259a9e.jpg
# /kaggle/input/global-wheat-detection/train/ddc160ce0.jpg
# /kaggle/input/global-wheat-detection/train/63c4e8cda.jpg
# /kaggle/input/global-wheat-detection/train/a346a6b04.jpg
# /kaggle/input/global-wheat-detection/train/fdbdb35fc.jpg
# /kaggle/input/global-wheat-detection/train/d2265cb91.jpg
# /kaggle/input/global-wheat-detection/train/2677d9124.jpg
# /kaggle/input/global-wheat-detection/train/4bdcb2c78.jpg
# /kaggle/input/global-wheat-detection/train/7fd06d0d9.jpg
# /kaggle/input/global-wheat-detection/train/c31bf0e39.jpg
# /kaggle/input/global-wheat-detection/train/901a650fb.jpg
# /kaggle/input/global-wheat-detection/train/ab4ff3cfa.jpg
# /kaggle/input/global-wheat-detection/train/8ca10d124.jpg
# /kaggle/input/global-wheat-detection/train/12d014f3e.jpg
# /kaggle/input/global-wheat-detection/train/02b6f199c.jpg
# /kaggle/input/global-wheat-detection/train/099c4c2b9.jpg
# /kaggle/input/global-wheat-detection/train/bc64c4252.jpg
# /kaggle/input/global-wheat-detection/train/6d27a58b7.jpg
# /kaggle/input/global-wheat-detection/train/afb9f53cd.jpg
# /kaggle/input/global-wheat-detection/train/3c1168fe0.jpg
# /kaggle/input/global-wheat-detection/train/241bbc684.jpg
# /kaggle/input/global-wheat-detection/train/16a0dc111.jpg
# /kaggle/input/global-wheat-detection/train/f121ee695.jpg
# /kaggle/input/global-wheat-detection/train/43bc260d9.jpg
# /kaggle/input/global-wheat-detection/train/8425a537b.jpg
# /kaggle/input/global-wheat-detection/train/0d7268752.jpg
# /kaggle/input/global-wheat-detection/train/0b2967a7a.jpg
# /kaggle/input/global-wheat-detection/train/da389bd36.jpg
# /kaggle/input/global-wheat-detection/train/4e652f7f1.jpg
# /kaggle/input/global-wheat-detection/train/0f43bb6d7.jpg
# /kaggle/input/global-wheat-detection/train/c7532e8e6.jpg
# /kaggle/input/global-wheat-detection/train/43f9b9fc5.jpg
# /kaggle/input/global-wheat-detection/train/bb3a2e25d.jpg
# /kaggle/input/global-wheat-detection/train/3e684e1cc.jpg
# /kaggle/input/global-wheat-detection/train/7d6074b93.jpg
# /kaggle/input/global-wheat-detection/train/b75c3bb71.jpg
# /kaggle/input/global-wheat-detection/train/a5cb30c38.jpg
# /kaggle/input/global-wheat-detection/train/b3ea991e1.jpg
# /kaggle/input/global-wheat-detection/train/4e6c05213.jpg
# /kaggle/input/global-wheat-detection/train/0594af5a7.jpg
# /kaggle/input/global-wheat-detection/train/5a76259a0.jpg
# /kaggle/input/global-wheat-detection/train/9c832432c.jpg
# /kaggle/input/global-wheat-detection/train/06812a4fc.jpg
# /kaggle/input/global-wheat-detection/train/d4811c163.jpg
# /kaggle/input/global-wheat-detection/train/161f20a53.jpg
# /kaggle/input/global-wheat-detection/train/4a8b1ad4a.jpg
# /kaggle/input/global-wheat-detection/train/0cbe3f32c.jpg
# /kaggle/input/global-wheat-detection/train/80d651f47.jpg
# /kaggle/input/global-wheat-detection/train/d493fef8c.jpg
# /kaggle/input/global-wheat-detection/train/c78edc091.jpg
# /kaggle/input/global-wheat-detection/train/7a9d1d1f2.jpg
# /kaggle/input/global-wheat-detection/train/504ec14ed.jpg
# /kaggle/input/global-wheat-detection/train/1443b3f7a.jpg
# /kaggle/input/global-wheat-detection/train/e05767cda.jpg
# /kaggle/input/global-wheat-detection/train/c8defc0d1.jpg
# /kaggle/input/global-wheat-detection/train/e817ba65e.jpg
# /kaggle/input/global-wheat-detection/train/37e705df9.jpg
# /kaggle/input/global-wheat-detection/train/9b4ad2587.jpg
# /kaggle/input/global-wheat-detection/train/9f1d83913.jpg
# /kaggle/input/global-wheat-detection/train/c4f586e0e.jpg
# /kaggle/input/global-wheat-detection/train/539ee1a56.jpg
# /kaggle/input/global-wheat-detection/train/342af9602.jpg
# /kaggle/input/global-wheat-detection/train/09b4141a6.jpg
# /kaggle/input/global-wheat-detection/train/18cefbf07.jpg
# /kaggle/input/global-wheat-detection/train/8b12ac747.jpg
# /kaggle/input/global-wheat-detection/train/9f63a1b8f.jpg
# /kaggle/input/global-wheat-detection/train/1951b2916.jpg
# /kaggle/input/global-wheat-detection/train/6811a6ee9.jpg
# /kaggle/input/global-wheat-detection/train/9bc09acf1.jpg
# /kaggle/input/global-wheat-detection/train/acb011afd.jpg
# /kaggle/input/global-wheat-detection/train/4ff1646a8.jpg
# /kaggle/input/global-wheat-detection/train/a4cc2650d.jpg
# /kaggle/input/global-wheat-detection/train/70282d0fc.jpg
# /kaggle/input/global-wheat-detection/train/a7a86396e.jpg
# /kaggle/input/global-wheat-detection/train/0dc2de69d.jpg
# /kaggle/input/global-wheat-detection/train/46c6a747a.jpg
# /kaggle/input/global-wheat-detection/train/dffff7fe4.jpg
# /kaggle/input/global-wheat-detection/train/d0912a485.jpg
# /kaggle/input/global-wheat-detection/train/a5cdd6362.jpg
# /kaggle/input/global-wheat-detection/train/68561559e.jpg
# /kaggle/input/global-wheat-detection/train/91ef6ef2b.jpg
# /kaggle/input/global-wheat-detection/train/085d0d511.jpg
# /kaggle/input/global-wheat-detection/train/bcf1dfc59.jpg
# /kaggle/input/global-wheat-detection/train/c87c9e9b2.jpg
# /kaggle/input/global-wheat-detection/train/fd95e2677.jpg
# /kaggle/input/global-wheat-detection/train/6f4d09643.jpg
# /kaggle/input/global-wheat-detection/train/dbe68e1c1.jpg
# /kaggle/input/global-wheat-detection/train/46930c2f2.jpg
# /kaggle/input/global-wheat-detection/train/505dfa497.jpg
# /kaggle/input/global-wheat-detection/train/f8d848989.jpg
# /kaggle/input/global-wheat-detection/train/15d56204e.jpg
# /kaggle/input/global-wheat-detection/train/43ab45d4b.jpg
# /kaggle/input/global-wheat-detection/train/e3471d3c2.jpg
# /kaggle/input/global-wheat-detection/train/595a30abe.jpg
# /kaggle/input/global-wheat-detection/train/5adddbf87.jpg
# /kaggle/input/global-wheat-detection/train/0874422e6.jpg
# /kaggle/input/global-wheat-detection/train/a44840527.jpg
# /kaggle/input/global-wheat-detection/train/035bdc07a.jpg
# /kaggle/input/global-wheat-detection/train/3684c0fae.jpg
# /kaggle/input/global-wheat-detection/train/250483997.jpg
# /kaggle/input/global-wheat-detection/train/eba970515.jpg
# /kaggle/input/global-wheat-detection/train/9ad34dab3.jpg
# /kaggle/input/global-wheat-detection/train/8f06b77e5.jpg
# /kaggle/input/global-wheat-detection/train/bfaa92629.jpg
# /kaggle/input/global-wheat-detection/train/74feae99f.jpg
# /kaggle/input/global-wheat-detection/train/1b399c9a7.jpg
# /kaggle/input/global-wheat-detection/train/cb7a2a690.jpg
# /kaggle/input/global-wheat-detection/train/26373af4b.jpg
# /kaggle/input/global-wheat-detection/train/d5af3d5a4.jpg
# /kaggle/input/global-wheat-detection/train/6dd6c4960.jpg
# /kaggle/input/global-wheat-detection/train/3744f2482.jpg
# /kaggle/input/global-wheat-detection/train/dc11d49a0.jpg
# /kaggle/input/global-wheat-detection/train/16d26f266.jpg
# /kaggle/input/global-wheat-detection/train/0787635a2.jpg
# /kaggle/input/global-wheat-detection/train/b79a35c8d.jpg
# /kaggle/input/global-wheat-detection/train/a93fe47af.jpg
# /kaggle/input/global-wheat-detection/train/f1016e0ea.jpg
# /kaggle/input/global-wheat-detection/train/aec95891a.jpg
# /kaggle/input/global-wheat-detection/train/7df975b07.jpg
# /kaggle/input/global-wheat-detection/train/2d65f77fb.jpg
# /kaggle/input/global-wheat-detection/train/ec40e9764.jpg
# /kaggle/input/global-wheat-detection/train/15babe6dd.jpg
# /kaggle/input/global-wheat-detection/train/294cc4475.jpg
# /kaggle/input/global-wheat-detection/train/14d2b1c3a.jpg
# /kaggle/input/global-wheat-detection/train/690c7d8f0.jpg
# /kaggle/input/global-wheat-detection/train/84d4ca3d3.jpg
# /kaggle/input/global-wheat-detection/train/e18bbfc52.jpg
# /kaggle/input/global-wheat-detection/train/625fca045.jpg
# /kaggle/input/global-wheat-detection/train/6a888dbcf.jpg
# /kaggle/input/global-wheat-detection/train/51f2e0a05.jpg
# /kaggle/input/global-wheat-detection/train/4d103d0aa.jpg
# /kaggle/input/global-wheat-detection/train/84411af4b.jpg
# /kaggle/input/global-wheat-detection/train/238c6cea4.jpg
# /kaggle/input/global-wheat-detection/train/ae1fcb590.jpg
# /kaggle/input/global-wheat-detection/train/b9c9c2559.jpg
# /kaggle/input/global-wheat-detection/train/0c7af1841.jpg
# /kaggle/input/global-wheat-detection/train/5c347dff7.jpg
# /kaggle/input/global-wheat-detection/train/d025ff56c.jpg
# /kaggle/input/global-wheat-detection/train/366187e59.jpg
# /kaggle/input/global-wheat-detection/train/be589b720.jpg
# /kaggle/input/global-wheat-detection/train/c7c00c1a3.jpg
# /kaggle/input/global-wheat-detection/train/2e867b62b.jpg
# /kaggle/input/global-wheat-detection/train/5e6a9d355.jpg
# /kaggle/input/global-wheat-detection/train/14716eed5.jpg
# /kaggle/input/global-wheat-detection/train/251ed33a8.jpg
# /kaggle/input/global-wheat-detection/train/f1b3454ff.jpg
# /kaggle/input/global-wheat-detection/train/0a4dc77c7.jpg
# /kaggle/input/global-wheat-detection/train/a1092f6d4.jpg
# /kaggle/input/global-wheat-detection/train/cce5cb631.jpg
# /kaggle/input/global-wheat-detection/train/14c66436c.jpg
# /kaggle/input/global-wheat-detection/train/0cca0ffc8.jpg
# /kaggle/input/global-wheat-detection/train/d03043abb.jpg
# /kaggle/input/global-wheat-detection/train/5016adc4b.jpg
# /kaggle/input/global-wheat-detection/train/a3ed252a3.jpg
# /kaggle/input/global-wheat-detection/train/3c378dd5d.jpg
# /kaggle/input/global-wheat-detection/train/be5ba0745.jpg
# /kaggle/input/global-wheat-detection/train/abb037b27.jpg
# /kaggle/input/global-wheat-detection/train/aa29cef4a.jpg
# /kaggle/input/global-wheat-detection/train/999d9d27d.jpg
# /kaggle/input/global-wheat-detection/train/c925fda69.jpg
# /kaggle/input/global-wheat-detection/train/9ebdbabff.jpg
# /kaggle/input/global-wheat-detection/train/4dd820b52.jpg
# /kaggle/input/global-wheat-detection/train/4de022cd4.jpg
# /kaggle/input/global-wheat-detection/train/1772cb764.jpg
# /kaggle/input/global-wheat-detection/train/7252dabad.jpg
# /kaggle/input/global-wheat-detection/train/7e971fbec.jpg
# /kaggle/input/global-wheat-detection/train/bfcaa59eb.jpg
# /kaggle/input/global-wheat-detection/train/8764d55c1.jpg
# /kaggle/input/global-wheat-detection/train/ab2dc3037.jpg
# /kaggle/input/global-wheat-detection/train/2d159a876.jpg
# /kaggle/input/global-wheat-detection/train/c8237c2e6.jpg
# /kaggle/input/global-wheat-detection/train/4a2662fae.jpg
# /kaggle/input/global-wheat-detection/train/8405c37aa.jpg
# /kaggle/input/global-wheat-detection/train/3cfbeabfc.jpg
# /kaggle/input/global-wheat-detection/train/44b73b40d.jpg
# /kaggle/input/global-wheat-detection/train/f87c3ecfe.jpg
# /kaggle/input/global-wheat-detection/train/42f5fe6a5.jpg
# /kaggle/input/global-wheat-detection/train/59ab1cdd7.jpg
# /kaggle/input/global-wheat-detection/train/4a44720ca.jpg
# /kaggle/input/global-wheat-detection/train/7eff8d967.jpg
# /kaggle/input/global-wheat-detection/train/a40ab0738.jpg
# /kaggle/input/global-wheat-detection/train/462d4d062.jpg
# /kaggle/input/global-wheat-detection/train/70b617a5e.jpg
# /kaggle/input/global-wheat-detection/train/10c433ecf.jpg
# /kaggle/input/global-wheat-detection/train/d7d200c0b.jpg
# /kaggle/input/global-wheat-detection/train/965b39ac8.jpg
# /kaggle/input/global-wheat-detection/train/13f7f0e24.jpg
# /kaggle/input/global-wheat-detection/train/93648317d.jpg
# /kaggle/input/global-wheat-detection/train/8af29abc4.jpg
# /kaggle/input/global-wheat-detection/train/4a609f334.jpg
# /kaggle/input/global-wheat-detection/train/fe0d6c114.jpg
# /kaggle/input/global-wheat-detection/train/44463860f.jpg
# /kaggle/input/global-wheat-detection/train/efa2ec01b.jpg
# /kaggle/input/global-wheat-detection/train/1c6e42234.jpg
# /kaggle/input/global-wheat-detection/train/620e2aee4.jpg
# /kaggle/input/global-wheat-detection/train/9a50eab86.jpg
# /kaggle/input/global-wheat-detection/train/d43e719c7.jpg
# /kaggle/input/global-wheat-detection/train/864210505.jpg
# /kaggle/input/global-wheat-detection/train/8ad93457c.jpg
# /kaggle/input/global-wheat-detection/train/7dac36eaa.jpg
# /kaggle/input/global-wheat-detection/train/f3fcfaa0d.jpg
# /kaggle/input/global-wheat-detection/train/02d662fa8.jpg
# /kaggle/input/global-wheat-detection/train/1c2c0786b.jpg
# /kaggle/input/global-wheat-detection/train/920923400.jpg
# /kaggle/input/global-wheat-detection/train/7aa682e0f.jpg
# /kaggle/input/global-wheat-detection/train/0f9100915.jpg
# /kaggle/input/global-wheat-detection/train/f4ce08038.jpg
# /kaggle/input/global-wheat-detection/train/00ea5e5ee.jpg
# /kaggle/input/global-wheat-detection/train/b95fd89e3.jpg
# /kaggle/input/global-wheat-detection/train/44fb6b8b2.jpg
# /kaggle/input/global-wheat-detection/train/fd5624913.jpg
# /kaggle/input/global-wheat-detection/train/a5904a10b.jpg
# /kaggle/input/global-wheat-detection/train/89fe13786.jpg
# /kaggle/input/global-wheat-detection/train/8ebda8cba.jpg
# /kaggle/input/global-wheat-detection/train/5f76c9a35.jpg
# /kaggle/input/global-wheat-detection/train/6e43d71ec.jpg
# /kaggle/input/global-wheat-detection/train/31b00c1ad.jpg
# /kaggle/input/global-wheat-detection/train/18be58eb6.jpg
# /kaggle/input/global-wheat-detection/train/8b67401f1.jpg
# /kaggle/input/global-wheat-detection/train/9dcba0cab.jpg
# /kaggle/input/global-wheat-detection/train/3eece2a34.jpg
# /kaggle/input/global-wheat-detection/train/1fab6aa6b.jpg
# /kaggle/input/global-wheat-detection/train/7c9096e13.jpg
# /kaggle/input/global-wheat-detection/train/1ef16dab1.jpg
# /kaggle/input/global-wheat-detection/train/e142e85ad.jpg
# /kaggle/input/global-wheat-detection/train/97b19f207.jpg
# /kaggle/input/global-wheat-detection/train/92c083d34.jpg
# /kaggle/input/global-wheat-detection/train/29e44e305.jpg
# /kaggle/input/global-wheat-detection/train/eb023ea4c.jpg
# /kaggle/input/global-wheat-detection/train/8498f5a6c.jpg
# /kaggle/input/global-wheat-detection/train/186c66a2c.jpg
# /kaggle/input/global-wheat-detection/train/5dc28374a.jpg
# /kaggle/input/global-wheat-detection/train/c0bc8d9f2.jpg
# /kaggle/input/global-wheat-detection/train/958c0ad3d.jpg
# /kaggle/input/global-wheat-detection/train/1c5f25cd1.jpg
# /kaggle/input/global-wheat-detection/train/010c93b99.jpg
# /kaggle/input/global-wheat-detection/train/6d262fcb8.jpg
# /kaggle/input/global-wheat-detection/train/718b1c7b8.jpg
# /kaggle/input/global-wheat-detection/train/8bc56fb34.jpg
# /kaggle/input/global-wheat-detection/train/832cf59eb.jpg
# /kaggle/input/global-wheat-detection/train/cc236443b.jpg
# /kaggle/input/global-wheat-detection/train/ce7375bad.jpg
# /kaggle/input/global-wheat-detection/train/29ffadaf3.jpg
# /kaggle/input/global-wheat-detection/train/3d39ed7cf.jpg
# /kaggle/input/global-wheat-detection/train/8d25532a5.jpg
# /kaggle/input/global-wheat-detection/train/c446944d6.jpg
# /kaggle/input/global-wheat-detection/train/3ff643a64.jpg
# /kaggle/input/global-wheat-detection/train/504dc181d.jpg
# /kaggle/input/global-wheat-detection/train/dd739823b.jpg
# /kaggle/input/global-wheat-detection/train/aa644920c.jpg
# /kaggle/input/global-wheat-detection/train/4532a128a.jpg
# /kaggle/input/global-wheat-detection/train/551902572.jpg
# /kaggle/input/global-wheat-detection/train/9181010cc.jpg
# /kaggle/input/global-wheat-detection/train/72f2eca3a.jpg
# /kaggle/input/global-wheat-detection/train/4a4a1d3e0.jpg
# /kaggle/input/global-wheat-detection/train/3dd44c524.jpg
# /kaggle/input/global-wheat-detection/train/6a9c581d2.jpg
# /kaggle/input/global-wheat-detection/train/ca4cb597b.jpg
# /kaggle/input/global-wheat-detection/train/2d06b68f0.jpg
# /kaggle/input/global-wheat-detection/train/6ea32891e.jpg
# /kaggle/input/global-wheat-detection/train/1909b7c5e.jpg
# /kaggle/input/global-wheat-detection/train/12a15fe77.jpg
# /kaggle/input/global-wheat-detection/train/5a8f53092.jpg
# /kaggle/input/global-wheat-detection/train/9b783b776.jpg
# /kaggle/input/global-wheat-detection/train/6b4169a72.jpg
# /kaggle/input/global-wheat-detection/train/f6a861545.jpg
# /kaggle/input/global-wheat-detection/train/6e3da4ae3.jpg
# /kaggle/input/global-wheat-detection/train/5b3ca5452.jpg
# /kaggle/input/global-wheat-detection/train/ef0a4ba44.jpg
# /kaggle/input/global-wheat-detection/train/bb835a3d2.jpg
# /kaggle/input/global-wheat-detection/train/43966050a.jpg
# /kaggle/input/global-wheat-detection/train/34b5b6acb.jpg
# /kaggle/input/global-wheat-detection/train/eba411885.jpg
# /kaggle/input/global-wheat-detection/train/3b829f3b0.jpg
# /kaggle/input/global-wheat-detection/train/b6fff3f79.jpg
# /kaggle/input/global-wheat-detection/train/c2d23766d.jpg
# /kaggle/input/global-wheat-detection/train/a9b1e5e29.jpg
# /kaggle/input/global-wheat-detection/train/3fe6394cd.jpg
# /kaggle/input/global-wheat-detection/train/fe125f8a6.jpg
# /kaggle/input/global-wheat-detection/train/8f5e128e3.jpg
# /kaggle/input/global-wheat-detection/train/47dcd5b34.jpg
# /kaggle/input/global-wheat-detection/train/b899eec9f.jpg
# /kaggle/input/global-wheat-detection/train/2bfadaa91.jpg
# /kaggle/input/global-wheat-detection/train/b9ffac7be.jpg
# /kaggle/input/global-wheat-detection/train/0c2d20111.jpg
# /kaggle/input/global-wheat-detection/train/e96942ed6.jpg
# /kaggle/input/global-wheat-detection/train/7fc944a16.jpg
# /kaggle/input/global-wheat-detection/train/36e469dbf.jpg
# /kaggle/input/global-wheat-detection/train/30a6d7d1d.jpg
# /kaggle/input/global-wheat-detection/train/83aae58fa.jpg
# /kaggle/input/global-wheat-detection/train/94f80c57a.jpg
# /kaggle/input/global-wheat-detection/train/de544d27c.jpg
# /kaggle/input/global-wheat-detection/train/131708dfd.jpg
# /kaggle/input/global-wheat-detection/train/9d8f6d301.jpg
# /kaggle/input/global-wheat-detection/train/133f92be6.jpg
# /kaggle/input/global-wheat-detection/train/7087bc3b2.jpg
# /kaggle/input/global-wheat-detection/train/2c3d40735.jpg
# /kaggle/input/global-wheat-detection/train/515e496a4.jpg
# /kaggle/input/global-wheat-detection/train/73ed111df.jpg
# /kaggle/input/global-wheat-detection/train/bce2fdc4d.jpg
# /kaggle/input/global-wheat-detection/train/8c4bdc8ba.jpg
# /kaggle/input/global-wheat-detection/train/818abfa22.jpg
# /kaggle/input/global-wheat-detection/train/f52ca5892.jpg
# /kaggle/input/global-wheat-detection/train/1b547b682.jpg
# /kaggle/input/global-wheat-detection/train/e0067b663.jpg
# /kaggle/input/global-wheat-detection/train/1b352d5fe.jpg
# /kaggle/input/global-wheat-detection/train/ba05c7bde.jpg
# /kaggle/input/global-wheat-detection/train/03a177626.jpg
# /kaggle/input/global-wheat-detection/train/fcb0f108a.jpg
# /kaggle/input/global-wheat-detection/train/b3c96d5ad.jpg
# /kaggle/input/global-wheat-detection/train/84d992b88.jpg
# /kaggle/input/global-wheat-detection/train/229716799.jpg
# /kaggle/input/global-wheat-detection/train/eb3cffc94.jpg
# /kaggle/input/global-wheat-detection/train/85f4d894b.jpg
# /kaggle/input/global-wheat-detection/train/e383c916b.jpg
# /kaggle/input/global-wheat-detection/train/86a6ad825.jpg
# /kaggle/input/global-wheat-detection/train/f3cce7df3.jpg
# /kaggle/input/global-wheat-detection/train/fa068329f.jpg
# /kaggle/input/global-wheat-detection/train/4a06c2f96.jpg
# /kaggle/input/global-wheat-detection/train/a81f68e82.jpg
# /kaggle/input/global-wheat-detection/train/948c989ef.jpg
# /kaggle/input/global-wheat-detection/train/ce367f7d6.jpg
# /kaggle/input/global-wheat-detection/train/ffb0f6eca.jpg
# /kaggle/input/global-wheat-detection/train/2c28cb6dd.jpg
# /kaggle/input/global-wheat-detection/train/e36eca699.jpg
# /kaggle/input/global-wheat-detection/train/864bafe51.jpg
# /kaggle/input/global-wheat-detection/train/51f539ed6.jpg
# /kaggle/input/global-wheat-detection/train/8f54c057d.jpg
# /kaggle/input/global-wheat-detection/train/86a279fe3.jpg
# /kaggle/input/global-wheat-detection/train/894baab2e.jpg
# /kaggle/input/global-wheat-detection/train/1c3032ee8.jpg
# /kaggle/input/global-wheat-detection/train/b0caf416d.jpg
# /kaggle/input/global-wheat-detection/train/6e07bfe69.jpg
# /kaggle/input/global-wheat-detection/train/49fbdf27c.jpg
# /kaggle/input/global-wheat-detection/train/c8b81529c.jpg
# /kaggle/input/global-wheat-detection/train/0ce3a22a3.jpg
# /kaggle/input/global-wheat-detection/train/6af5a0a2b.jpg
# /kaggle/input/global-wheat-detection/train/311a8b9db.jpg
# /kaggle/input/global-wheat-detection/train/f5093f57d.jpg
# /kaggle/input/global-wheat-detection/train/71d2a4b3c.jpg
# /kaggle/input/global-wheat-detection/train/f74ede365.jpg
# /kaggle/input/global-wheat-detection/train/31c085c60.jpg
# /kaggle/input/global-wheat-detection/train/4972999e9.jpg
# /kaggle/input/global-wheat-detection/train/9adca8ff8.jpg
# /kaggle/input/global-wheat-detection/train/c9ade75be.jpg
# /kaggle/input/global-wheat-detection/train/b65e07813.jpg
# /kaggle/input/global-wheat-detection/train/e4ba46588.jpg
# /kaggle/input/global-wheat-detection/train/9aa5dec56.jpg
# /kaggle/input/global-wheat-detection/train/98db75bde.jpg
# /kaggle/input/global-wheat-detection/train/b1643e118.jpg
# /kaggle/input/global-wheat-detection/train/4789e5c97.jpg
# /kaggle/input/global-wheat-detection/train/12b724773.jpg
# /kaggle/input/global-wheat-detection/train/c14c1e300.jpg
# /kaggle/input/global-wheat-detection/train/26eada42f.jpg
# /kaggle/input/global-wheat-detection/train/0a181bbb4.jpg
# /kaggle/input/global-wheat-detection/train/69c5b6df3.jpg
# /kaggle/input/global-wheat-detection/train/999645d8a.jpg
# /kaggle/input/global-wheat-detection/train/8d318219c.jpg
# /kaggle/input/global-wheat-detection/train/2cffefd1a.jpg
# /kaggle/input/global-wheat-detection/train/d4abcc41e.jpg
# /kaggle/input/global-wheat-detection/train/a7e9ac14b.jpg
# /kaggle/input/global-wheat-detection/train/66d91891d.jpg
# /kaggle/input/global-wheat-detection/train/0df7f89c3.jpg
# /kaggle/input/global-wheat-detection/train/c022ddc42.jpg
# /kaggle/input/global-wheat-detection/train/fb52ca9b2.jpg
# /kaggle/input/global-wheat-detection/train/81e06a4cd.jpg
# /kaggle/input/global-wheat-detection/train/cbab952fe.jpg
# /kaggle/input/global-wheat-detection/train/e7f4f02a7.jpg
# /kaggle/input/global-wheat-detection/train/e5c45da08.jpg
# /kaggle/input/global-wheat-detection/train/976d1eb84.jpg
# /kaggle/input/global-wheat-detection/train/18df0fea9.jpg
# /kaggle/input/global-wheat-detection/train/3f23c607b.jpg
# /kaggle/input/global-wheat-detection/train/0cf7ef43d.jpg
# /kaggle/input/global-wheat-detection/train/744ea960b.jpg
# /kaggle/input/global-wheat-detection/train/199350a76.jpg
# /kaggle/input/global-wheat-detection/train/9f8c17c70.jpg
# /kaggle/input/global-wheat-detection/train/2b32a4cc4.jpg
# /kaggle/input/global-wheat-detection/train/0bbb17b82.jpg
# /kaggle/input/global-wheat-detection/train/4b95f5e5a.jpg
# /kaggle/input/global-wheat-detection/train/2d2c79df1.jpg
# /kaggle/input/global-wheat-detection/train/cc81eb577.jpg
# /kaggle/input/global-wheat-detection/train/4285f0271.jpg
# /kaggle/input/global-wheat-detection/train/6d1ff0f34.jpg
# /kaggle/input/global-wheat-detection/train/18059ff19.jpg
# /kaggle/input/global-wheat-detection/train/b3d2304bf.jpg
# /kaggle/input/global-wheat-detection/train/87c6acaae.jpg
# /kaggle/input/global-wheat-detection/train/20ebdfc4b.jpg
# /kaggle/input/global-wheat-detection/train/817ab3693.jpg
# /kaggle/input/global-wheat-detection/train/3049b3745.jpg
# /kaggle/input/global-wheat-detection/train/8a5310dc4.jpg
# /kaggle/input/global-wheat-detection/train/f49d9b7d6.jpg
# /kaggle/input/global-wheat-detection/train/b2b578c39.jpg
# /kaggle/input/global-wheat-detection/train/67bc08594.jpg
# /kaggle/input/global-wheat-detection/train/0cbb43d45.jpg
# /kaggle/input/global-wheat-detection/train/bd5cb3bc5.jpg
# /kaggle/input/global-wheat-detection/train/69809f5c0.jpg
# /kaggle/input/global-wheat-detection/train/c8c449bf0.jpg
# /kaggle/input/global-wheat-detection/train/ea0e9e846.jpg
# /kaggle/input/global-wheat-detection/train/80111be66.jpg
# /kaggle/input/global-wheat-detection/train/f3bc43304.jpg
# /kaggle/input/global-wheat-detection/train/4cbb2b7bd.jpg
# /kaggle/input/global-wheat-detection/train/37191de77.jpg
# /kaggle/input/global-wheat-detection/train/9658b9c3c.jpg
# /kaggle/input/global-wheat-detection/train/e1c0e82fd.jpg
# /kaggle/input/global-wheat-detection/train/d96205316.jpg
# /kaggle/input/global-wheat-detection/train/dbd433d29.jpg
# /kaggle/input/global-wheat-detection/train/1bcb0e91e.jpg
# /kaggle/input/global-wheat-detection/train/9ddb20382.jpg
# /kaggle/input/global-wheat-detection/train/0e8557b27.jpg
# /kaggle/input/global-wheat-detection/train/e0a241bd5.jpg
# /kaggle/input/global-wheat-detection/train/bbec6e514.jpg
# /kaggle/input/global-wheat-detection/train/45d452a61.jpg
# /kaggle/input/global-wheat-detection/train/9ea2ef32b.jpg
# /kaggle/input/global-wheat-detection/train/29dc6c59a.jpg
# /kaggle/input/global-wheat-detection/train/f2c0e95ec.jpg
# /kaggle/input/global-wheat-detection/train/a06dbb0fd.jpg
# /kaggle/input/global-wheat-detection/train/49dcb7dd3.jpg
# /kaggle/input/global-wheat-detection/train/d2e7465f0.jpg
# /kaggle/input/global-wheat-detection/train/0ebac9a23.jpg
# /kaggle/input/global-wheat-detection/train/54c4ea343.jpg
# ...
# /kaggle/input/global-wheat-detection/train/d145202eb.jpg
# /kaggle/input/global-wheat-detection/train/d9c104dce.jpg
# /kaggle/input/global-wheat-detection/train/e2523989d.jpg
# /kaggle/input/global-wheat-detection/train/57570effa.jpg
# /kaggle/input/global-wheat-detection/train/019d1c76a.jpg
# /kaggle/input/global-wheat-detection/train/d771bb084.jpg
# /kaggle/input/global-wheat-detection/train/7b7b3c08f.jpg
# /kaggle/input/global-wheat-detection/train/23a4b904a.jpg
# /kaggle/input/global-wheat-detection/train/5a0e2133c.jpg
# /kaggle/input/global-wheat-detection/train/c6654ff53.jpg
# /kaggle/input/global-wheat-detection/train/c04bc8abb.jpg
# /kaggle/input/global-wheat-detection/train/a61806345.jpg
# /kaggle/input/global-wheat-detection/train/bb67d5c2e.jpg
# /kaggle/input/global-wheat-detection/train/5aaf5b11f.jpg
# /kaggle/input/global-wheat-detection/train/fec6edf64.jpg
# /kaggle/input/global-wheat-detection/train/3782f5786.jpg
# /kaggle/input/global-wheat-detection/train/13050d5e4.jpg
# /kaggle/input/global-wheat-detection/train/d098bdc9b.jpg
# /kaggle/input/global-wheat-detection/train/70581f4f9.jpg
# /kaggle/input/global-wheat-detection/train/fa9d798b1.jpg
# /kaggle/input/global-wheat-detection/train/afe608129.jpg
# /kaggle/input/global-wheat-detection/train/9ef3c0a46.jpg
# /kaggle/input/global-wheat-detection/train/695ae4a12.jpg
# /kaggle/input/global-wheat-detection/train/47e218059.jpg
# /kaggle/input/global-wheat-detection/train/7b0840687.jpg
# /kaggle/input/global-wheat-detection/train/26263f228.jpg
# /kaggle/input/global-wheat-detection/train/78752f185.jpg
# /kaggle/input/global-wheat-detection/train/1a13195b8.jpg
# /kaggle/input/global-wheat-detection/train/a39887dc2.jpg
# /kaggle/input/global-wheat-detection/train/ea72a0c0c.jpg
# /kaggle/input/global-wheat-detection/train/26c2b1c78.jpg
# /kaggle/input/global-wheat-detection/train/386e36c35.jpg
# /kaggle/input/global-wheat-detection/train/42d5e8791.jpg
# /kaggle/input/global-wheat-detection/train/116a6fceb.jpg
# /kaggle/input/global-wheat-detection/train/59ade64e1.jpg
# /kaggle/input/global-wheat-detection/train/2474376a6.jpg
# /kaggle/input/global-wheat-detection/train/4a7825bbe.jpg
# /kaggle/input/global-wheat-detection/train/3fd9db710.jpg
# /kaggle/input/global-wheat-detection/train/f27d2e19c.jpg
# /kaggle/input/global-wheat-detection/train/e277cec54.jpg
# /kaggle/input/global-wheat-detection/train/bf0631017.jpg
# /kaggle/input/global-wheat-detection/train/61bcac952.jpg
# /kaggle/input/global-wheat-detection/train/a2e7fd80f.jpg
# /kaggle/input/global-wheat-detection/train/4b3f6a162.jpg
# /kaggle/input/global-wheat-detection/train/3f2eddbe8.jpg
# /kaggle/input/global-wheat-detection/train/48bdfec34.jpg
# /kaggle/input/global-wheat-detection/train/dc620a761.jpg
# /kaggle/input/global-wheat-detection/train/8dd8f0ca6.jpg
# /kaggle/input/global-wheat-detection/train/1696dab5e.jpg
# /kaggle/input/global-wheat-detection/train/3c377bf39.jpg
# /kaggle/input/global-wheat-detection/train/3542457e2.jpg
# /kaggle/input/global-wheat-detection/train/46630486d.jpg
# /kaggle/input/global-wheat-detection/train/a586f39dd.jpg
# /kaggle/input/global-wheat-detection/train/636069d07.jpg
# /kaggle/input/global-wheat-detection/train/9aea92dce.jpg
# /kaggle/input/global-wheat-detection/train/f358b3414.jpg
# /kaggle/input/global-wheat-detection/train/8afea785a.jpg
# /kaggle/input/global-wheat-detection/train/61a658026.jpg
# /kaggle/input/global-wheat-detection/train/b61e3461d.jpg
# /kaggle/input/global-wheat-detection/train/79ce67248.jpg
# /kaggle/input/global-wheat-detection/train/d79169f0e.jpg
# /kaggle/input/global-wheat-detection/train/82775d15c.jpg
# /kaggle/input/global-wheat-detection/train/b40d7ae4e.jpg
# /kaggle/input/global-wheat-detection/train/482d7c843.jpg
# /kaggle/input/global-wheat-detection/train/eddff557c.jpg
# /kaggle/input/global-wheat-detection/train/4bfb54f09.jpg
# /kaggle/input/global-wheat-detection/train/c34dd05a3.jpg
# /kaggle/input/global-wheat-detection/train/849061b2b.jpg
# /kaggle/input/global-wheat-detection/train/b0daf69ce.jpg
# /kaggle/input/global-wheat-detection/train/7cca42bf6.jpg
# /kaggle/input/global-wheat-detection/train/6dfeb6f7a.jpg
# /kaggle/input/global-wheat-detection/train/2d93cee57.jpg
# /kaggle/input/global-wheat-detection/train/a94d39f89.jpg
# /kaggle/input/global-wheat-detection/train/9bbee18cc.jpg
# /kaggle/input/global-wheat-detection/train/2ae9c276f.jpg
# /kaggle/input/global-wheat-detection/train/005b0d8bb.jpg
# /kaggle/input/global-wheat-detection/train/84053c39b.jpg
# /kaggle/input/global-wheat-detection/train/e4c9b3866.jpg
# /kaggle/input/global-wheat-detection/train/569ea0f59.jpg
# /kaggle/input/global-wheat-detection/train/b6eb131d8.jpg
# /kaggle/input/global-wheat-detection/train/19ecc4446.jpg
# /kaggle/input/global-wheat-detection/train/d00a142f1.jpg
# /kaggle/input/global-wheat-detection/train/c5c70baa6.jpg
# /kaggle/input/global-wheat-detection/train/84f077ae5.jpg
# /kaggle/input/global-wheat-detection/train/c88836133.jpg
# /kaggle/input/global-wheat-detection/train/86e843e5e.jpg
# /kaggle/input/global-wheat-detection/train/5a0db55d8.jpg
# /kaggle/input/global-wheat-detection/train/5ea4aa57a.jpg
# /kaggle/input/global-wheat-detection/train/62be58f7d.jpg
# /kaggle/input/global-wheat-detection/train/ee8a5cbbc.jpg
# /kaggle/input/global-wheat-detection/train/7718ea4e9.jpg
# /kaggle/input/global-wheat-detection/train/655c1ffdd.jpg
# /kaggle/input/global-wheat-detection/train/058ad1382.jpg
# /kaggle/input/global-wheat-detection/train/4a304fb45.jpg
# /kaggle/input/global-wheat-detection/train/00b5c6764.jpg
# /kaggle/input/global-wheat-detection/train/b21ca086c.jpg
# /kaggle/input/global-wheat-detection/train/967982605.jpg
# /kaggle/input/global-wheat-detection/train/44546c006.jpg
# /kaggle/input/global-wheat-detection/train/cbbc58a4c.jpg
# /kaggle/input/global-wheat-detection/train/9790095bb.jpg
# /kaggle/input/global-wheat-detection/train/6a62af644.jpg
# /kaggle/input/global-wheat-detection/train/4132df01d.jpg
# /kaggle/input/global-wheat-detection/train/5366196ef.jpg
# /kaggle/input/global-wheat-detection/train/7803a8211.jpg
# /kaggle/input/global-wheat-detection/train/2689d2bb4.jpg
# /kaggle/input/global-wheat-detection/train/87998b065.jpg
# /kaggle/input/global-wheat-detection/train/c88635e09.jpg
# /kaggle/input/global-wheat-detection/train/d8f09768d.jpg
# /kaggle/input/global-wheat-detection/train/f99daf7f6.jpg
# /kaggle/input/global-wheat-detection/train/dae984d6a.jpg
# /kaggle/input/global-wheat-detection/train/16daa81b4.jpg
# /kaggle/input/global-wheat-detection/train/d5ac4c940.jpg
# /kaggle/input/global-wheat-detection/train/6ac5ecca6.jpg
# /kaggle/input/global-wheat-detection/train/467dee148.jpg
# /kaggle/input/global-wheat-detection/train/2ccec6dcc.jpg
# /kaggle/input/global-wheat-detection/train/347ecba39.jpg
# /kaggle/input/global-wheat-detection/train/99d5eb61c.jpg
# /kaggle/input/global-wheat-detection/train/c1bea7def.jpg
# /kaggle/input/global-wheat-detection/train/fa7ceeea7.jpg
# /kaggle/input/global-wheat-detection/train/c49ed83ce.jpg
# /kaggle/input/global-wheat-detection/train/c01baaca6.jpg
# /kaggle/input/global-wheat-detection/train/35b935b6c.jpg
# /kaggle/input/global-wheat-detection/train/b77e8c906.jpg
# /kaggle/input/global-wheat-detection/train/5d6d64e39.jpg
# /kaggle/input/global-wheat-detection/train/5041b4b98.jpg
# /kaggle/input/global-wheat-detection/train/382bf4ed7.jpg
# /kaggle/input/global-wheat-detection/train/97851b9c6.jpg
# /kaggle/input/global-wheat-detection/train/73dbabe1f.jpg
# /kaggle/input/global-wheat-detection/train/d3a6e23a3.jpg
# /kaggle/input/global-wheat-detection/train/900d273d2.jpg
# /kaggle/input/global-wheat-detection/train/d64fc42f7.jpg
# /kaggle/input/global-wheat-detection/train/51bf3f631.jpg
# /kaggle/input/global-wheat-detection/train/b65a59339.jpg
# /kaggle/input/global-wheat-detection/train/1bf4fb6e5.jpg
# /kaggle/input/global-wheat-detection/train/f21d6d68c.jpg
# /kaggle/input/global-wheat-detection/train/d136f8db2.jpg
# /kaggle/input/global-wheat-detection/train/a750327c3.jpg
# /kaggle/input/global-wheat-detection/train/6efc51980.jpg
# /kaggle/input/global-wheat-detection/train/fe3d17ee2.jpg
# /kaggle/input/global-wheat-detection/train/23eb6b3d5.jpg
# /kaggle/input/global-wheat-detection/train/20c7cc731.jpg
# /kaggle/input/global-wheat-detection/train/625311180.jpg
# /kaggle/input/global-wheat-detection/train/2e1a15f76.jpg
# /kaggle/input/global-wheat-detection/train/8dcecab03.jpg
# /kaggle/input/global-wheat-detection/train/b1100369a.jpg
# /kaggle/input/global-wheat-detection/train/6c9cf179f.jpg
# /kaggle/input/global-wheat-detection/train/e7527a057.jpg
# /kaggle/input/global-wheat-detection/train/91c7fb84e.jpg
# /kaggle/input/global-wheat-detection/train/22eabfde5.jpg
# /kaggle/input/global-wheat-detection/train/3dc3a72f9.jpg
# /kaggle/input/global-wheat-detection/train/6a739d41b.jpg
# /kaggle/input/global-wheat-detection/train/51cd1fe14.jpg
# /kaggle/input/global-wheat-detection/train/4883da2a8.jpg
# /kaggle/input/global-wheat-detection/train/c6b4933f7.jpg
# /kaggle/input/global-wheat-detection/train/0bff84dd0.jpg
# /kaggle/input/global-wheat-detection/train/c94e8a60c.jpg
# /kaggle/input/global-wheat-detection/train/ed7c302a2.jpg
# /kaggle/input/global-wheat-detection/train/49c3e4f6e.jpg
# /kaggle/input/global-wheat-detection/train/f5c2143dc.jpg
# /kaggle/input/global-wheat-detection/train/582bcd162.jpg
# /kaggle/input/global-wheat-detection/train/d8cae4d1b.jpg
# /kaggle/input/global-wheat-detection/train/d03bcfba1.jpg
# /kaggle/input/global-wheat-detection/train/a5c07f2af.jpg
# /kaggle/input/global-wheat-detection/train/22f341965.jpg
# /kaggle/input/global-wheat-detection/train/06fdd4941.jpg
# /kaggle/input/global-wheat-detection/train/684a2c62a.jpg
# /kaggle/input/global-wheat-detection/train/ed23785c8.jpg
# /kaggle/input/global-wheat-detection/train/b96e8e1f5.jpg
# /kaggle/input/global-wheat-detection/train/8301297cc.jpg
# /kaggle/input/global-wheat-detection/train/ce803c694.jpg
# /kaggle/input/global-wheat-detection/train/4646dcda7.jpg
# /kaggle/input/global-wheat-detection/train/82f88bab4.jpg
# /kaggle/input/global-wheat-detection/train/4def855a8.jpg
# /kaggle/input/global-wheat-detection/train/49d76c63d.jpg
# /kaggle/input/global-wheat-detection/train/da0c40152.jpg
# /kaggle/input/global-wheat-detection/train/4870004e7.jpg
# /kaggle/input/global-wheat-detection/train/96efbda67.jpg
# /kaggle/input/global-wheat-detection/train/2752325a7.jpg
# /kaggle/input/global-wheat-detection/train/a764cea1f.jpg
# /kaggle/input/global-wheat-detection/train/b0a22c629.jpg
# /kaggle/input/global-wheat-detection/train/278038027.jpg
# /kaggle/input/global-wheat-detection/train/dc7c60052.jpg
# /kaggle/input/global-wheat-detection/train/af101aa29.jpg
# /kaggle/input/global-wheat-detection/train/14d024cc4.jpg
# /kaggle/input/global-wheat-detection/train/6bfbcee57.jpg
# /kaggle/input/global-wheat-detection/train/c328e6c68.jpg
# /kaggle/input/global-wheat-detection/train/581eaf87b.jpg
# /kaggle/input/global-wheat-detection/train/152d16ce7.jpg
# /kaggle/input/global-wheat-detection/train/c89aed93e.jpg
# /kaggle/input/global-wheat-detection/train/70b693efe.jpg
# /kaggle/input/global-wheat-detection/train/7ea16f78f.jpg
# /kaggle/input/global-wheat-detection/train/d2f56e67a.jpg
# /kaggle/input/global-wheat-detection/train/dae78abf2.jpg
# /kaggle/input/global-wheat-detection/train/bc226ebfd.jpg
# /kaggle/input/global-wheat-detection/train/70d39ea64.jpg
# /kaggle/input/global-wheat-detection/train/76bd18142.jpg
# /kaggle/input/global-wheat-detection/train/e991f2e06.jpg
# /kaggle/input/global-wheat-detection/train/19255ce1d.jpg
# /kaggle/input/global-wheat-detection/train/0d2948e6d.jpg
# /kaggle/input/global-wheat-detection/train/8201b54e5.jpg
# /kaggle/input/global-wheat-detection/train/1e2735260.jpg
# /kaggle/input/global-wheat-detection/train/c26cd234a.jpg
# /kaggle/input/global-wheat-detection/train/432d13b1c.jpg
# /kaggle/input/global-wheat-detection/train/c580831f7.jpg
# /kaggle/input/global-wheat-detection/train/dc8e4942d.jpg
# /kaggle/input/global-wheat-detection/train/81d47ffe8.jpg
# /kaggle/input/global-wheat-detection/train/fa55f0519.jpg
# /kaggle/input/global-wheat-detection/train/3c14db5cc.jpg
# /kaggle/input/global-wheat-detection/train/93ad786cf.jpg
# /kaggle/input/global-wheat-detection/train/f1a8585e0.jpg
# /kaggle/input/global-wheat-detection/train/c7df66915.jpg
# /kaggle/input/global-wheat-detection/train/3cf4abfb6.jpg
# /kaggle/input/global-wheat-detection/train/26f09dc76.jpg
# /kaggle/input/global-wheat-detection/train/c808023f3.jpg
# /kaggle/input/global-wheat-detection/train/0e0809a3d.jpg
# /kaggle/input/global-wheat-detection/train/4227725a7.jpg
# /kaggle/input/global-wheat-detection/train/ca56c6d41.jpg
# /kaggle/input/global-wheat-detection/train/7826a88b5.jpg
# /kaggle/input/global-wheat-detection/train/b2de96e22.jpg
# /kaggle/input/global-wheat-detection/train/ac8365ca4.jpg
# /kaggle/input/global-wheat-detection/train/6639b23df.jpg
# /kaggle/input/global-wheat-detection/train/e60108508.jpg
# /kaggle/input/global-wheat-detection/train/8a5741c74.jpg
# /kaggle/input/global-wheat-detection/train/34c5e70d5.jpg
# /kaggle/input/global-wheat-detection/train/ba9133208.jpg
# /kaggle/input/global-wheat-detection/train/e84e8709a.jpg
# /kaggle/input/global-wheat-detection/train/967ff723d.jpg
# /kaggle/input/global-wheat-detection/train/eb42212f3.jpg
# /kaggle/input/global-wheat-detection/train/375a4795b.jpg
# /kaggle/input/global-wheat-detection/train/d3e9389e1.jpg
# /kaggle/input/global-wheat-detection/train/d1d96eae9.jpg
# /kaggle/input/global-wheat-detection/train/e8a274b57.jpg
# /kaggle/input/global-wheat-detection/train/7f1833df2.jpg
# /kaggle/input/global-wheat-detection/train/29f09fa58.jpg
# /kaggle/input/global-wheat-detection/train/45958be5e.jpg
# /kaggle/input/global-wheat-detection/train/db0fdecd3.jpg
# /kaggle/input/global-wheat-detection/train/6d993d18d.jpg
# /kaggle/input/global-wheat-detection/train/785755a9c.jpg
# /kaggle/input/global-wheat-detection/train/f9c4d2466.jpg
# /kaggle/input/global-wheat-detection/train/ecad4b636.jpg
# /kaggle/input/global-wheat-detection/train/d5cc960f7.jpg
# /kaggle/input/global-wheat-detection/train/0424c00e4.jpg
# /kaggle/input/global-wheat-detection/train/da0e870d9.jpg
# /kaggle/input/global-wheat-detection/train/465a8a521.jpg
# /kaggle/input/global-wheat-detection/train/9613afcb6.jpg
# /kaggle/input/global-wheat-detection/train/258c0d943.jpg
# /kaggle/input/global-wheat-detection/train/1e6d99635.jpg
# /kaggle/input/global-wheat-detection/train/9cb0a5504.jpg
# /kaggle/input/global-wheat-detection/train/eb56a281b.jpg
# /kaggle/input/global-wheat-detection/train/f98dd1c09.jpg
# /kaggle/input/global-wheat-detection/train/a9b3451c9.jpg
# /kaggle/input/global-wheat-detection/train/f6afe5443.jpg
# /kaggle/input/global-wheat-detection/train/e6e510348.jpg
# /kaggle/input/global-wheat-detection/train/3dd22103f.jpg
# /kaggle/input/global-wheat-detection/train/aebb5ab04.jpg
# /kaggle/input/global-wheat-detection/train/59afb9acf.jpg
# /kaggle/input/global-wheat-detection/train/0c3d9007c.jpg
# /kaggle/input/global-wheat-detection/train/5b032a98f.jpg
# /kaggle/input/global-wheat-detection/train/4b04d64f9.jpg
# /kaggle/input/global-wheat-detection/train/be03606e0.jpg
# /kaggle/input/global-wheat-detection/train/777fa71f7.jpg
# /kaggle/input/global-wheat-detection/train/b69255534.jpg
# /kaggle/input/global-wheat-detection/train/31eb0625d.jpg
# /kaggle/input/global-wheat-detection/train/57ae1baf6.jpg
# /kaggle/input/global-wheat-detection/train/769309456.jpg
# /kaggle/input/global-wheat-detection/train/26b7c3188.jpg
# /kaggle/input/global-wheat-detection/train/0a73f8a0f.jpg
# /kaggle/input/global-wheat-detection/train/e14f4de23.jpg
# /kaggle/input/global-wheat-detection/train/56fe78aae.jpg
# /kaggle/input/global-wheat-detection/train/4cd4207d8.jpg
# /kaggle/input/global-wheat-detection/train/6ca0ef373.jpg
# /kaggle/input/global-wheat-detection/train/58c6beb2d.jpg
# /kaggle/input/global-wheat-detection/train/5ac7c8105.jpg
# /kaggle/input/global-wheat-detection/train/8d9aaa54d.jpg
# /kaggle/input/global-wheat-detection/train/58adb478f.jpg
# /kaggle/input/global-wheat-detection/train/4a654c127.jpg
# /kaggle/input/global-wheat-detection/train/99886a700.jpg
# /kaggle/input/global-wheat-detection/train/7b9dfab15.jpg
# /kaggle/input/global-wheat-detection/train/79eca0678.jpg
# /kaggle/input/global-wheat-detection/train/667b4a999.jpg

# %% [markdown]
# # YOLOv5

# %% [markdown]
# ## Config

# %%
import seaborn as sns
import ast
from tqdm import trange, tqdm
from colorama import Fore
from enum import Enum
from glob import glob

# For Data preparation
from sklearn.preprocessing import *
from sklearn.model_selection import *
from sklearn.metrics import *

# %%
class Config(Enum):
    def __str__(self):
        return self.value
    
    TRAIN_CSV = '../input/global-wheat-detection/train.csv'
    TEST_CSV = "../input/global-wheat-detection/sample_submission.csv"
    TRAIN_DIR = "../input/global-wheat-detection/train"
    TEST_DIR = "../input/global-wheat-detection/test"
    OUTPUT_PATH = "./yolov5/output"
    IMG_SHAPE = 1024
    CONFIG_FILENAME = "ws_data"
    EPOCHS = 20
    BATCH_SIZE = 8

# %%
def process_data(data_df, image_id_col, bbox_col, label_col, path_col, config_filename = 'data', test_size = 0.2):
    """
    Build dataset for Yolo training
        + Expect form: (label, x_center, y_center, width, height)
        + return df_train, df_val
    """
    os.system('git clone https://github.com/ultralytics/yolov5.git')
    OUTPUT_FOLDER_NAME = Config.OUTPUT_PATH.value.split('/')[-1]
    if not os.path.exists(Config.OUTPUT_PATH.value):
        os.system(
            f'''
                cd ./yolov5
                mkdir {OUTPUT_FOLDER_NAME} 
                cd {OUTPUT_FOLDER_NAME}
                mkdir images
                mkdir labels
                cd images
                mkdir train
                mkdir validation
                cd ..
                cd labels
                mkdir train
                mkdir validation
                cd ../../
                tree {OUTPUT_FOLDER_NAME}
                cd ../
            '''
        )
    
    # Convert string form of list to original form
    data_df.bbox = data_df.bbox.apply(ast.literal_eval)
    
    # Encoding all labels
    mapper = {k: d for d, k in enumerate(set(data_df[label_col]))}
    data_df[label_col] = data_df[label_col].apply(lambda x: int(mapper[x]))
    
    # Group the bounding boxes wrt image_id, label_col and path_col
    data_df = data_df.groupby(by = [image_id_col, label_col, path_col])[bbox_col].apply(list).reset_index(name = bbox_col)
    
    # Divide data into train and val set
    df_train, df_val = train_test_split(data_df, test_size = test_size, random_state = 1234, shuffle = True)
    df_train = df_train.reset_index(drop = True)
    df_val = df_val.reset_index(drop = True)    
    
    print(f"[INFO] Train_SHAPE : {df_train.shape}, VAL_SHAPE: {df_val.shape}")
    data_dict = {'train': df_train, 'validation': df_val}
    for data_type, data in data_dict.items():
        for idx in trange(len(data), desc=f'Processing {data_type}...', bar_format="{l_bar}%s{bar:50}%s{r_bar}" % (Fore.CYAN, Fore.RESET), position=0, leave=True):
            row = data.iloc[idx]
            image_name = row[image_id_col]
            bounding_boxes = row[bbox_col]
            label = row[label_col]
            path = row[path_col]
            yolo_data = []
            for bbox in bounding_boxes:
                x = bbox[0]
                y = bbox[1]
                w = bbox[2]
                h = bbox[3]
                
                x_center = x + w / 2
                y_center = y + h / 2
                
                x_center, y_center, w, h = tuple(map(lambda x: x/Config.IMG_SHAPE.value, (x_center, y_center, w, h)))
                yolo_data.append([label, x_center, y_center, w, h])
                
            yolo_data = np.array(yolo_data)
            np.savetxt(
                f"{Config.OUTPUT_PATH.value}/labels/{data_type}/{image_name}.txt",
                yolo_data,
                fmt = ["%d", "%f", "%f", "%f", "%f"]
            )
            os.system(
                f"""
                cp {path} {Config.OUTPUT_PATH.value}/images/{data_type}/{path.split("/")[-1]}

                """
            )
    with open(f"./yolov5/{config_filename}.yaml", "w+") as file_:
        file_.write(
            f"""
            
            train: {OUTPUT_FOLDER_NAME}/images/train
            val: {OUTPUT_FOLDER_NAME}/images/validation
            nc: {len(mapper)}
            names: {list(mapper.keys())}
            
            """
        )
    file_.close()
    print("[INFO] Done with data processing")

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv(Config.TRAIN_CSV.value)
df_test = pd.read_csv(Config.TEST_CSV.value)

df['path'] = df.image_id.apply(lambda x: f'{Config.TRAIN_DIR.value}/{x}.jpg')
df_test['path'] = df_test.image_id.apply(lambda x: f'{Config.TEST_DIR.value}/{x}.jpg')

df['label'] = ['Wheat']*len(df)

print(df.dtypes)
df.head()
# Out:
# image_id    object
# width        int64
# height       int64
# bbox        object
# source      object
# path        object
# label       object
# dtype: object
#     image_id  width  height                         bbox   source  \
# 0  b6ab77fd7   1024    1024   [834.0, 222.0, 56.0, 36.0]  usask_1
# 1  b6ab77fd7   1024    1024  [226.0, 548.0, 130.0, 58.0]  usask_1
# 2  b6ab77fd7   1024    1024  [377.0, 504.0, 74.0, 160.0]  usask_1
# 3  b6ab77fd7   1024    1024  [834.0, 95.0, 109.0, 107.0]  usask_1
# 4  b6ab77fd7   1024    1024  [26.0, 144.0, 124.0, 117.0]  usask_1
#
#                                                 path  label
# 0  ../input/global-wheat-detection/train/b6ab77fd...  Wheat
# 1  ../input/global-wheat-detection/train/b6ab77fd...  Wheat
# 2  ../input/global-wheat-detection/train/b6ab77fd...  Wheat
# 3  ../input/global-wheat-detection/train/b6ab77fd...  Wheat
# 4  ../input/global-wheat-detection/train/b6ab77fd...  Wheat

# %% [markdown]
# ## Train YOLO model

# %%
process_data(data_df = df, 
             image_id_col = "image_id", 
             bbox_col = "bbox", 
             label_col = "label",
             path_col = "path", 
             config_filename = Config.CONFIG_FILENAME.value)
# Out:
# Cloning into 'yolov5'...
# output
# ├── images
# │   ├── train
# │   └── validation
# └── labels
#     ├── train
#     └── validation
#
# 6 directories, 0 files
# [INFO] Train_SHAPE : (2698, 4), VAL_SHAPE: (675, 4)
# Processing train...: 100%|██████████████████████████████████████████████████| 2698/2698 [00:29<00:00, 90.92it/s]
# Processing validation...: 100%|██████████████████████████████████████████████████| 675/675 [00:07<00:00, 87.89it/s]
# [INFO] Done with data processing

# %%
def train(model_name, config_filename, preTrainedWeights_path = None):
    mapper = {}
    for idx, model_ in enumerate(glob('yolov5/models/*yaml')):
        mapper[idx + 1] = model_
        print(f"{idx + 1} => {model_.split('/')[-1].split('.')[0]}")
    
    model = mapper[int(input(f'Select model from idx'))]
    if preTrainedWeights_path:
        os.system(
        f'''
        python yolov5/train.py --img {Config.IMG_SHAPE.value} --batch {Config.BATCH_SIZE.value} --epochs {Config.EPOCHS.value} --data yolov5/{config_filename}.yaml --cfg {model} --name {model_name} --weights {preTrainedweights_path}
        '''
        )
    else:
        os.system(
            f"""
                python yolov5/train.py --img {Config.IMG_SHAPE.value} --batch {Config.BATCH_SIZE.value} --epochs {Config.EPOCHS.value} --data yolov5/{config_filename}.yaml --cfg {model} --name {model_name}
            """
        )
train(model_name = 'ws_yolov5', config_filename = Config.CONFIG_FILENAME.value)
# Out:
# 1 => yolov5m
# 2 => yolov5s
# 3 => yolov5n
# 4 => yolov5l
# 5 => yolov5x
# Select model from idx 2
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# train: weights=yolov5/yolov5s.pt, cfg=yolov5/models/yolov5s.yaml, data=yolov5/ws_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=8, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=ws_yolov5, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-40-gb0ba101 torch 1.9.1 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5/yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 39.5MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7022326 parameters, 7022326 gradients
#
# Transferred 342/349 items from yolov5/yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: Blur(always_apply=False, p=0.01, blur_limit=(3, 7)), MedianBlur(always_apply=False, p=0.01, blur_limit=(3, 7)), ToGray(always_apply=False, p=0.01), CLAHE(always_apply=False, p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/kaggle/working/yolov5/output/labels/train' images and labels...133 found, 0 missing, 0 empty, 0 corrupt:   5%|▍         | 133/2698 [00:00<00:01, 1329.81it/s]
# train: Scanning '/kaggle/working/yolov5/output/labels/train' images and labels...2698 found, 0 missing, 0 empty, 0 corrupt: 100%|██████████| 2698/2698 [00:01<00:00, 1533.83it/s]
# train: New cache created: /kaggle/working/yolov5/output/labels/train.cache
# val: Scanning '/kaggle/working/yolov5/output/labels/validation' images and labels...675 found, 0 missing, 0 empty, 0 corrupt: 100%|██████████| 675/675 [00:00<00:00, 748.70it/s]
# val: New cache created: /kaggle/working/yolov5/output/labels/validation.cache
# Plotting labels to yolov5/runs/train/ws_yolov5/labels.jpg...
#
# AutoAnchor: 5.72 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to yolov5/runs/train/ws_yolov5
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/19     4.91G   0.07942    0.3452         0       124      1024: 100%|██████████| 338/338 [05:15<00:00,  1.07it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:21<00:00,  2.03it/s]
#                  all        675      29686      0.486      0.705      0.562      0.204
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/19     4.91G    0.0579    0.3352         0       150      1024: 100%|██████████| 338/338 [04:59<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:19<00:00,  2.22it/s]
#                  all        675      29686      0.708      0.724      0.736      0.204
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/19     4.91G   0.05249    0.3415         0       215      1024: 100%|██████████| 338/338 [04:58<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:20<00:00,  2.08it/s]
#                  all        675      29686       0.85       0.76      0.839      0.338
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/19     4.91G   0.04638    0.3294         0        89      1024: 100%|██████████| 338/338 [05:00<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:19<00:00,  2.20it/s]
#                  all        675      29686       0.91      0.849      0.916      0.453
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/19     4.91G   0.04218    0.3242         0       145      1024: 100%|██████████| 338/338 [04:57<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.36it/s]
#                  all        675      29686       0.91      0.872      0.929      0.492
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/19     4.91G   0.04073    0.3147         0        90      1024: 100%|██████████| 338/338 [04:57<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.27it/s]
#                  all        675      29686      0.915      0.873      0.932        0.5
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/19     4.91G    0.0393    0.3126         0        61      1024: 100%|██████████| 338/338 [04:57<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.33it/s]
#                  all        675      29686      0.922      0.875      0.937      0.511
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/19     4.91G   0.03862    0.3082         0        49      1024: 100%|██████████| 338/338 [04:58<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.38it/s]
#                  all        675      29686      0.915      0.891      0.941      0.519
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/19     4.91G   0.03791    0.3012         0        63      1024: 100%|██████████| 338/338 [04:56<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.30it/s]
#                  all        675      29686      0.927      0.881      0.942      0.522
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/19     4.91G   0.03733    0.3033         0        65      1024: 100%|██████████| 338/338 [04:57<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:17<00:00,  2.41it/s]
#                  all        675      29686      0.924      0.891      0.945      0.529
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/19     4.91G   0.03685    0.3002         0       130      1024: 100%|██████████| 338/338 [04:58<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.33it/s]
#                  all        675      29686      0.919      0.894      0.943      0.531
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/19     4.91G   0.03649    0.3008         0        83      1024: 100%|██████████| 338/338 [04:58<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:19<00:00,  2.26it/s]
#                  all        675      29686      0.923      0.893      0.945       0.53
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      12/19     4.91G   0.03643    0.3038         0        60      1024: 100%|██████████| 338/338 [05:01<00:00,  1.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.37it/s]
#                  all        675      29686      0.922      0.895      0.944       0.53
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      13/19     4.91G   0.03608    0.2955         0       163      1024: 100%|██████████| 338/338 [05:02<00:00,  1.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:17<00:00,  2.40it/s]
#                  all        675      29686      0.928      0.894      0.947      0.538
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      14/19     4.91G   0.03574    0.2953         0       104      1024: 100%|██████████| 338/338 [05:03<00:00,  1.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.26it/s]
#                  all        675      29686      0.922      0.895      0.946      0.537
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      15/19     4.91G   0.03568    0.2959         0       113      1024: 100%|██████████| 338/338 [05:07<00:00,  1.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.29it/s]
#                  all        675      29686      0.925      0.897      0.947      0.538
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      16/19     4.91G   0.03562    0.2959         0       167      1024: 100%|██████████| 338/338 [05:07<00:00,  1.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.27it/s]
#                  all        675      29686      0.924      0.897      0.947      0.541
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      17/19     4.91G   0.03533     0.297         0       148      1024: 100%|██████████| 338/338 [05:05<00:00,  1.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.32it/s]
#                  all        675      29686      0.933       0.89      0.948      0.544
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      18/19     4.91G   0.03517    0.2955         0       139      1024: 100%|██████████| 338/338 [05:03<00:00,  1.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:17<00:00,  2.42it/s]
#                  all        675      29686      0.927      0.899      0.949      0.543
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      19/19     4.91G   0.03502    0.2912         0       139      1024: 100%|██████████| 338/338 [05:04<00:00,  1.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:18<00:00,  2.39it/s]
#                  all        675      29686      0.929      0.897      0.949      0.544
#
# 20 epochs completed in 1.787 hours.
# Optimizer stripped from yolov5/runs/train/ws_yolov5/weights/last.pt, 14.8MB
# Optimizer stripped from yolov5/runs/train/ws_yolov5/weights/best.pt, 14.8MB
#
# Validating yolov5/runs/train/ws_yolov5/weights/best.pt...
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|██████████| 43/43 [00:56<00:00,  1.32s/it]
#                  all        675      29686      0.929      0.897      0.949      0.544
# Results saved to yolov5/runs/train/ws_yolov5

# %%
def predict(images_path:"path to the test images", weights_path: "path to the weights folder"):
    """
    Helper function to make predictions over images using Yolo
    """
    os.system(
        f"""
            python yolov5/detect.py --source {images_path} --weights {weights_path}
        """)

predict(images_path = "../input/global-wheat-detection/test",
       weights_path = "yolov5/runs/train/ws_yolov54/weights/best.pt")
# Out:
# detect: weights=['yolov5/runs/train/ws_yolov54/weights/best.pt'], source=../input/global-wheat-detection/test, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-40-gb0ba101 torch 1.9.1 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Traceback (most recent call last):
#   File "yolov5/detect.py", line 252, in <module>
#     main(opt)
#   File "yolov5/detect.py", line 247, in main
#     run(**vars(opt))
#   File "/opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "yolov5/detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/kaggle/working/yolov5/models/common.py", line 306, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, map_location=device)
#   File "/kaggle/working/yolov5/models/experimental.py", line 96, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location=map_location)  # load
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'yolov5/runs/train/ws_yolov54/weights/best.pt'
